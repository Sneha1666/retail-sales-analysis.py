# %%
# ============================
# 1. IMPORT LIBRARIES
# ============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ============================
# 2. CREATE DATASET (REAL WORLD STYLE)
# ============================

data = {
    "Order_Date": pd.date_range(start="2024-01-01", periods=12, freq="ME"),
    "Region": ["South", "North", "East", "West"] * 3,
    "Category": ["Furniture", "Technology", "Office Supplies"] * 4,
    "Sales": [200, 500, 150, 700, 300, 250, 400, 600, 350, 450, 550, 650],
    "Profit": [20, 80, 10, 120, 30, 25, 50, 100, 40, 60, 70, 90]
}

df = pd.DataFrame(data)

# ============================
# 3. BASIC INFORMATION
# ============================
print("\n📌 FIRST 5 ROWS")
print(df.head())

print("\n📌 DATA INFO")
print(df.info())

print("\n📌 MISSING VALUES")
print(df.isnull().sum())

print("\n📌 STATISTICS")
print(df.describe())

# ============================
# 4. DATA ANALYSIS
# ============================

# Sales by Region
region_sales = df.groupby("Region")["Sales"].sum()
print("\n📊 Sales by Region")
print(region_sales)

# Profit by Category
category_profit = df.groupby("Category")["Profit"].sum()
print("\n📊 Profit by Category")
print(category_profit)

# Monthly Sales Trend
monthly_sales = df.groupby("Order_Date")["Sales"].sum()

# ============================
# 5. VISUALIZATION
# ============================

# --- Sales by Region ---
plt.figure()
region_sales.plot(kind="bar")
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.show()

# --- Profit by Category ---
plt.figure()
category_profit.plot(kind="bar")
plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.show()

# --- Sales Trend Over Time ---
plt.figure()
plt.plot(monthly_sales.index, monthly_sales.values, marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# --- Sales vs Profit ---
plt.figure()
plt.scatter(df["Sales"], df["Profit"])
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# ============================
# 6. CORRELATION ANALYSIS
# ============================
print("\n📌 CORRELATION MATRIX")
corr = df[["Sales", "Profit"]].corr()
print(corr)

plt.figure()
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# ============================
# 7. FINAL INSIGHTS
# ============================
print("\n📌 FINAL INSIGHTS")
print("1. Sales differ across regions.")
print("2. Technology gives higher profit.")
print("3. Sales and profit are positively related.")
print("4. Sales show monthly variation.")
# Out:
# 📌 FIRST 5 ROWS
#   Order_Date Region         Category  Sales  Profit
# 0 2024-01-31  South        Furniture    200      20
# 1 2024-02-29  North       Technology    500      80
# 2 2024-03-31   East  Office Supplies    150      10
# 3 2024-04-30   West        Furniture    700     120
# 4 2024-05-31  South       Technology    300      30
#
# 📌 DATA INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_Date  12 non-null     datetime64[ns]
#  1   Region      12 non-null     object
#  2   Category    12 non-null     object
#  3   Sales       12 non-null     int64
#  4   Profit      12 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 612.0+ bytes
# None
#
# 📌 MISSING VALUES
# Order_Date    0
# Region        0
# Category      0
# Sales         0
# Profit        0
# dtype: int64
#
# 📌 STATISTICS
# ...
